# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv("./bollywood_full.csv")

# %%
df.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# Interesting fields: Original_title, genres, story, actors

# %%
# Let the input be genres and output be something like Original_title: , Summary: , actors:

# %%
df["genres"][0].split("|")
# Out:
# ['Action', 'Drama', 'War']

# %%
df["input"] = df.genres

# %%
for i, item in enumerate(df["input"]):
    df["input"][i] = df["input"][i].split("|")

# %%
df["input"]
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 4325                 [Drama]
# 4326                 [Drama]
# 4327         [Drama, Family]
# 4328                 [Drama]
# 4329                 [Drama]
# Name: input, Length: 4330, dtype: object

# %%
titles = df["original_title"]

# %%
story = df["story"]

# %%
actors = df["actors"]

# %%
output = "title: " + titles + "\n" + "Story: " + story + "\n" + "Suitable Actors: " + actors

# %%
df["input"]
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 4325                 [Drama]
# 4326                 [Drama]
# 4327         [Drama, Family]
# 4328                 [Drama]
# 4329                 [Drama]
# Name: input, Length: 4330, dtype: object

# %%
df["output"] = output
df["output"]
# Out:
# 0       title: Uri: The Surgical Strike\nStory: Divide...
# 1       title: Battalion 609\nStory: The story revolve...
# 2       title: The Accidental Prime Minister\nStory: B...
# 3       title: Why Cheat India\nStory: The movie focus...
# 4       title: Evening Shadows\nStory: While gay right...
#                               ...
# 4325    title: Samadhi\nStory: The story is based on t...
# 4326    title: Sangram\nStory: After the death of his ...
# 4327                                                  NaN
# 4328    title: Sheesh Mahal\nStory: Thakur Jaspal Sing...
# 4329                                                  NaN
# Name: output, Length: 4330, dtype: object

# %%
dataset = pd.DataFrame({"input" :df["input"], "output" : df["output"]})

# %%
dataset = dataset.dropna()

# %%
for i in range(0, len(dataset["output"])):
    print("----------------------")
    print(dataset["output"][i])
    print("----------------------")
# Out:
# ----------------------
# title: Uri: The Surgical Strike
# Story: Divided over five chapters  the film chronicles the events of the surgical strike conducted by the Indian military against suspected militants in Pakistan occupied Kashmir. It tells the story of the 11 tumultuous events over which the operation was carried out. Indian army special forces carry out a covert operation to avenge the killing of fellow army men at their base by a terrorist group.
# Suitable Actors: Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|
# ----------------------
# ----------------------
# title: Battalion 609
# ...

# %%
dataset.to_csv("./bollywood_processed.csv")
